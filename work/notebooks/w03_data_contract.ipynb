# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# 1. Unit of Analysis + Time Window

One row represents one webpage in the content refresh dataset.

The dataset summarizes webpage search performance over a recent time period using metrics such as impressions, clicks, CTR, average position, engagement rate, and trend direction.
"""))
# Out:
# # 1. Unit of Analysis + Time Window
#
# One row represents one webpage in the content refresh dataset.
#
# The dataset summarizes webpage search performance over a recent time period using metrics such as impressions, clicks, CTR, average position, engagement rate, and trend direction.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
display(Markdown("""
# 2. Fields

## Features
- search_volume
- competition
- ctr
- avg_position
- engagement_rate
- word_count
- content_type

## Label
- trend_direction

## Context
- content_id
- client_id

## Excluded
- content_id (used only as an identifier)
- client_id (used only to identify the client and not for prediction)

These excluded fields are identifiers and do not provide useful predictive information.
"""))
# Out:
# # 2. Fields
#
# ## Features
# - search_volume
# - competition
# - ctr
# - avg_position
# - engagement_rate
# - word_count
# - content_type
#
# ## Label
# - trend_direction
#
# ## Context
# - content_id
# - client_id
#
# ## Excluded
# - content_id (used only as an identifier)
# - client_id (used only to identify the client and not for prediction)
#
# These excluded fields are identifiers and do not provide useful predictive information.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import os
import subprocess
import pandas as pd

REPO_URL = "https://github.com/asfina9591-u/flyrank-ml"
REPO_DIR = "flyrank-ml"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nFirst 5 rows:")
display(df.head())

print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(10))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Rows: 30000
# Columns: 44
#
# First 5 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
display(Markdown("""
# 4. Data Limits

This dataset can identify patterns in webpage performance, but it cannot explain the exact reasons behind changes in search rankings.

The analysis is based on observed data and should be used for decision-support. It cannot prove causation or predict Google's search algorithm.
"""))
# Out:
# # 4. Data Limits
#
# This dataset can identify patterns in webpage performance, but it cannot explain the exact reasons behind changes in search rankings.
#
# The analysis is based on observed data and should be used for decision-support. It cannot prove causation or predict Google's search algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
