# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# 1. Two Paper Findings + My Methodology Questions

### Finding 1
The research suggests that machine learning can improve the prioritization of webpages for content refresh compared to a simple rule-based approach.

**Methodology Question:** How was the target label created, and does it accurately represent pages that truly needed refreshing?

---

### Finding 2
The paper reports that grouped validation produces more realistic model evaluation.

**Methodology Question:** Were pages from the same client completely separated between the training and testing sets to avoid data leakage?

These questions help evaluate whether the reported results are reliable and suitable for real-world use.
"""))
# Out:
# # 1. Two Paper Findings + My Methodology Questions
#
# ### Finding 1
# The research suggests that machine learning can improve the prioritization of webpages for content refresh compared to a simple rule-based approach.
#
# **Methodology Question:** How was the target label created, and does it accurately represent pages that truly needed refreshing?
#
# ---
#
# ### Finding 2
# The paper reports that grouped validation produces more realistic model evaluation.
#
# **Methodology Question:** Were pages from the same client completely separated between the training and testing sets to avoid data leakage?
#
# These questions help evaluate whether the reported results are reliable and suitable for real-world use.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
import os
import subprocess
import json
import pandas as pd

REPO_URL = "https://github.com/asfina9591-u/flyrank-ml"
REPO_DIR = "flyrank-ml"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git","clone",REPO_URL],check=True)

os.chdir(REPO_DIR)

subprocess.run(["python","scripts/run_all.py"])

with open("outputs/model_results.json") as f:
    results = json.load(f)

baseline = results["baseline"]["baseline_precision_at_50"]
rf = results["models"]["random_forest"]["precision_at_50"]

comparison = pd.DataFrame({
    "Evaluation":["Baseline Rule","Random Forest"],
    "Precision@50":[baseline,rf]
})

display(comparison)
# Out:
#       Evaluation  Precision@50
# 0  Baseline Rule          0.24
# 1  Random Forest          0.74

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
display(Markdown("""
# 3. Leakage Audit

The final feature set excludes fields that directly reveal the prediction target.

Excluded fields include:

- trend_direction
- trend_pct
- content_id
- client_id

These fields were removed because they either identify records or contain information that could leak the correct answer into the model.
"""))
# Out:
# # 3. Leakage Audit
#
# The final feature set excludes fields that directly reveal the prediction target.
#
# Excluded fields include:
#
# - trend_direction
# - trend_pct
# - content_id
# - client_id
#
# These fields were removed because they either identify records or contain information that could leak the correct answer into the model.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
display(Markdown("""
# 4. Claim Rewrite

### Original Claim

The Random Forest model predicts which webpages should always be refreshed.

### Safer Claim

The Random Forest model identified patterns associated with webpages that may benefit from content refresh. The results provide decision-support based on observed data and should not be interpreted as proof of future search performance.
"""))
# Out:
# # 4. Claim Rewrite
#
# ### Original Claim
#
# The Random Forest model predicts which webpages should always be refreshed.
#
# ### Safer Claim
#
# The Random Forest model identified patterns associated with webpages that may benefit from content refresh. The results provide decision-support based on observed data and should not be interpreted as proof of future search performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
