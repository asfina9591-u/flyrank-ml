# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os
import subprocess

REPO_URL = "https://github.com/asfina9591-u/flyrank-ml"
REPO_DIR = "flyrank-ml"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
print("Data exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Current directory: /content/flyrank-ml
# Data exists: True

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
display(Markdown("""
## Research Question

**Decision:** Decide which website pages should be refreshed first.

**Action:** Content editors or SEO teams will update the selected pages.

**Cost of a wrong recommendation:** Refreshing the wrong page wastes time and resources, while missing a declining page can lead to lower search traffic and reduced visibility.

**Why ML:** Machine learning can combine several page features to rank pages more accurately than simple rule-based methods.
"""))
# Out:
# ## Research Question
#
# **Decision:** Decide which website pages should be refreshed first.
#
# **Action:** Content editors or SEO teams will update the selected pages.
#
# **Cost of a wrong recommendation:** Refreshing the wrong page wastes time and resources, while missing a declining page can lead to lower search traffic and reduced visibility.
#
# **Why ML:** Machine learning can combine several page features to rank pages more accurately than simple rule-based methods.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

corr = df["search_volume"].corr(df["impressions_90d"])
print("Correlation between search volume and impressions:", round(corr, 3))

print("\nTrend direction counts:")
print(df["trend_direction"].value_counts())
# Out:
# Number of rows: 30000
# Number of columns: 44
# Correlation between search volume and impressions: 0.001
#
# Trend direction counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## 4. Careful words: what I can and can't claim

This project provides **decision-support** based on the anonymized dataset. The findings describe **observed**, **measured**, and **directional** patterns in the data that may help prioritize pages for content refresh.

However, this project **does not prove causation**, does not predict Google's algorithm, and cannot guarantee future search rankings or traffic. The results should be used only to support decisions and should be validated with additional data.
"""))
# Out:
# ## 4. Careful words: what I can and can't claim
#
# This project provides **decision-support** based on the anonymized dataset. The findings describe **observed**, **measured**, and **directional** patterns in the data that may help prioritize pages for content refresh.
#
# However, this project **does not prove causation**, does not predict Google's algorithm, and cannot guarantee future search rankings or traffic. The results should be used only to support decisions and should be validated with additional data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
